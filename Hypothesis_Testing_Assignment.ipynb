# %% [markdown]
# <a href="https://colab.research.google.com/github/SowjanyaKiran/sowjanya-/blob/main/Hypothesis_Testing_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Hypothesis Formulation:**
#
# **A company claims that their new energy drink increases focus and alertness.
# Formulate the null and alternative hypotheses for testing this claim.**
#
# **Ans:**
#
# **Step 1:Define the Null and Alternative Hypothesis**
#
# **Null Hypothesis ($H_0$):** The new energy drink has no effect on focus and alertness.
#
#   $μ_1$ = $μ_0$ (The energy drink has no effect on focus and alertness.)
#
#
# **Alternative Hypothesis ($H_1$):** The new energy drink increases focus and alertness.
#
#  $μ_1$ > $μ_0$ (The energy drink increases focus and alertness.)
#
# **Step 2: Interpretation**
#
# **If we reject $H_0$(because the test statistic is significant at the chosen confidence level, e.g., 95% or 99%):**
#  We have enough statistical evidence to support the claim that the energy drink significantly increases focus and alertness.
#
# **If we fail to reject $H_1$ (because the test statistic is not significant):**
#  There is no strong evidence to conclude that the drink has a positive effect. This does not mean the drink has no effect at all—just that the study did not find enough proof to support the claim.

# %% [markdown]
# **2.Significance Level Selection:**
#
# **A researcher is conducting a study on the effects of exercise on weight loss. What significance level should they choose for their hypothesis test and why?**
#
# **Ans:**
#
# The significance level (𝛼) is a threshold used in hypothesis testing to determine whether to reject the null hypothesis (H₀). It represents the probability of making a Type I error, which occurs when we incorrectly reject a true null hypothesis (a false positive).
#
# ![image.png](data:image/png;base64,...)
#
# **Common Significance Levels:**
#
# **𝛼 = 0.05 α=0.05 (5%) → Most commonly used**
#
# **Balanced approach:** It controls both Type I (false positive) and Type II (false negative) errors at reasonable levels. Used in most scientific and health studies where consequences of errors are not life-threatening.
#
# **𝛼 = 0.01 α=0.01 (1%) → Stronger evidence required**
#
# Used in highly sensitive studies, such as medical trials or drug effectiveness. Reduces the chance of falsely concluding that exercise causes weight loss when it does not. Recommended if weight loss interventions have high risks (e.g., side effects, severe health implications).
#
#  **𝛼 = 0.10 α=0.10 (10%) → More lenient approach**
#
# Used in exploratory research or pilot studies where the goal is to detect trends rather than confirm strong evidence. Higher risk of Type I error, meaning more false positives. Not recommended for studies that impact health decisions.
#
# Best Choice for This Case Since weight loss due to exercise is a health-related topic but not as critical as drug testing, a reasonable choice is:
#
# **𝛼 = 0.05 α=0.05 (5%)**
#
# Balances false positives and false negatives. Widely accepted in health and fitness research. Strong enough to support claims without being too strict.
#
# **Final Recommendation**
# If the study is preliminary/exploratory, α=0.10 can be used. If the study needs strong scientific evidence,α=0.05 is best. If the study has serious health implications, α=0.01 should be used. Conclusion: For most exercise and weight loss studies,α=0.05 is the standard choice as it provides a good balance between accuracy and statistical power.

# %% [markdown]
# **3.Interpreting p-values:**
#
# **In a study investigating the effectiveness of a new teaching method, the calculated p-value is 0.03. What does this p-value indicate about the null hypothesis?**
#
# **Ans:**
#
# p-value indicates strong evidence to reject the null hypothesis, while a large p-value suggests the data is consistent with the null hypothesis and does not provide enough evidence to reject it
#
# ![image.png](data:image/png;base64,...)
#
# **Key Interpretations:**
#
# **Small p-value (p ≤ 𝛼) →** Reject H₀ (strong evidence against the null hypothesis).The null hypothesis would likely be rejected. In statistical hypothesis testing, the p-value is compared to a predetermined significance level (alpha), commonly set at 0.05. If the p-value is less than or equal to the significance level (p ≤ α), the null hypothesis is rejected. In this case, 0.03 is less than 0.05, suggesting there is sufficient evidence to reject the null hypothesis.
#
# **Large p-value (p > 𝛼) →** Fail to reject H₀ (not enough evidence to support the alternative hypothesis).
#
# **Conclusion:**
#
# The null hypothesis likely stated that the new teaching method has no effect. Therefore, rejecting the null hypothesis suggests that the new teaching method does have a statistically significant effect on the outcome being measured

# %% [markdown]
# **4.Type I and Type II Errors:**
#
# **Describe a scenario in which a Type I error could occur in hypothesis testing. How does it differ from a Type II error?**
#
# **Ans:**
#
# ![image.png](data:image/png;base64,...)
#
#
# **Scenario for a Type I Error:**
#
# Imagine a bank using fraud detection software to identify fraudulent transactions.
#
# **Null Hypothesis ($H_0$):** The transaction is legitimate.
#
# **Alternative Hypothesis ($H_1$):** The transaction is fraudulent.
#
# A Type I error occurs if the bank incorrectly rejects the null hypothesis, meaning it wrongly flags a real transaction as fraud. This could lead to blocking a customers card, causing frustration and inconvenience.
#
# **Scenario for a Type II Error:**
#
# A Type II error happens if the bank fails to reject the null hypothesis when it should, meaning it misses detecting an actual fraudulent transaction. This could allow a hacker to steal money from a customer’s account, leading to financial loss.
#
# **Difference Between Type I and Type II Errors:**
#
# 1. Type I Error (False Positive)
#
#     a. Rejecting $H_0$ when it is actually true.
#
#     b. A real transaction is wrongly flagged as fraud.
#
#     c. Causes inconvenience to the customer.
#
# 2. Type II Error (False Negative)
#
#     a. Failing to reject $H_0$ when it is actually false.
#
#     b. A fraudulent transaction is mistakenly approved.
#
#     c. Causes financial loss to the customer.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **5.Right-tailed Hypothesis Testing:**
#
# **A manufacturer claims that their new light bulb lasts, on average, more than 1000 hours. Conduct a right-tailed hypothesis test with a significance level of 0.05, given a sample mean of 1050 hours and a sample standard deviation of 50 hours.**
#
# **Ans:**
#
# **Step 1: Define the Hypotheses**
#
# **Null Hypothesis ($H_0$):** The average lifespan of the light bulbs is 1000 hours.
#
# $H_0$:μ=1000
#
# **Alternative Hypothesis ($H_1$):** The average lifespan of the light bulbs is greater than 1000 hours.
#
# $H_1$:𝜇>1000
#
# This makes it a right-tailed test because we are testing if the mean is significantly greater than 1000 hours.
#
# **Step 2: Given Data**
#
# Sample mean ($\bar x $) = 1050 hours
#
# Population mean ($𝜇_0) = 1000 hours
#
# Sample standard deviation (𝑠) = 50 hours
#
# Sample size (𝑛) is not given, so we assume n is large enough for the Central Limit Theorem to apply.
#
# Significance level (𝛼) = 0.05
#
# **Step 3: Compute the Test Statistic**
#
# Since the population standard deviation is unknown, we use the t-test formula:
# The t-score formula: $t=(\bar x -\mu_0) \div (s /\sqrt(n))$
#
# Since n is not provided, can you confirm the sample size? This is crucial for finding the critical value and making a decision.
#
# ![image.png](data:image/png;base64,...)

# %%
import scipy.stats as stats
import numpy as np

sample_mean = 1050  # Sample mean lifespan
sample_std = 50      # Sample standard deviation
sample_size = 30     # Sample size
claimed_mean = 1000  # Claimed population mean
alpha = 0.05         # Significance level

# Degrees of freedom
df = sample_size - 1

# Compute t-statistic
t_statistic = (sample_mean - claimed_mean) / (sample_std / np.sqrt(sample_size))

# Find critical t-value for right-tailed test (alpha = 0.05)
t_critical = stats.t.ppf(1 - alpha, df)

# Compute p-value for right-tailed test
p_value = 1 - stats.t.cdf(t_statistic, df)

# Print results
print(f"T-Statistic: {t_statistic:.3f}")
print(f"Critical T-Value: {t_critical:.3f}")
print(f"P-Value: {p_value:.6f}")

# Decision Rule

if t_statistic > t_critical:
    print("Reject the null hypothesis: The average lifespan is significantly greater than 1000 hours.")
else:
    print("Fail to reject the null hypothesis: No significant evidence that the average lifespan is greater than 1000 hours.")
# Out:
# T-Statistic: 5.477
# Critical T-Value: 1.699
# P-Value: 0.000003
# Reject the null hypothesis: The average lifespan is significantly greater than 1000 hours.

# %% [markdown]
# **6.Two-Tailed Hypothesis Testing:**
#
# **A researcher wants to determine if there is a difference in mean exam scores between two groups of students. Formulate the null and alternative hypotheses for this study as a two-tailed test.**
#
# **Ans:**
#
# ![images TWO TAIL.jpg](data:image/jpeg;base64,...)
#
# **Step 1: Define the Hypotheses**
#
# Null Hypothesis ($H_0$):
# There is no significant difference in the mean exam scores between the two groups.
#
# $H_0$:$μ_1$=$μ_2$
#
# or equivalently,
# $H_0$:$𝜇_1$=$μ_2$
#
# where:$μ_1$= Mean exam score of Group 1.
#
#  $𝜇_2$= Mean exam score of Group 2.
#
#  Alternative Hypothesis ($H_1$):
# There is a significant difference in the mean exam scores between the two groups (either higher or lower).
#
# $H_1$:$𝜇_1$ ≠ $𝜇_2$
#
# or equivalently,
# $H_1$:$𝜇_1$ - $𝜇_2$≠0
#
# **Step 2: Explanation of Two-Tailed Test**
#
# A two-tailed test checks for any difference between the two groups (not just higher or lower).
# This means we are looking for deviations in either direction (Group 1 could score higher or lower than Group 2).
# The rejection region is split equally between both tails of the distribution.
#
# **Step 3: Decision Criteria**
#
# If the p-value < 𝛼 (e.g., 0.05), we reject
# $H_0$ , meaning there is a significant difference in exam scores.
#
# If the p-value > 𝛼 , we fail to reject  $H_0$ , meaning there is no strong evidence of a difference.
#
#
# **Final Answer:**
#
# **Null Hypothesis ($𝐻_0$):** There is no significant difference in the mean exam scores of the two groups.
#
# **Alternative Hypothesis ($H_1$):** There is a significant difference in the mean exam scores of the two groups (either higher or lower).

# %%
import scipy.stats as stats
import numpy as np

def two_tailed_t_test(mean1, std1, n1, mean2, std2, n2, alpha=0.05):
    # Compute the t-score
    t_score = (mean1 - mean2) / np.sqrt((std1**2 / n1) + (std2**2 / n2))

    # Degrees of freedom approximation
    df = min(n1 - 1, n2 - 1)

    # Critical t-value for a two-tailed test
    t_critical = stats.t.ppf(1 - alpha/2, df)

    # Print results
    print(f"Degrees of Freedom: {df}")
    print(f"Calculated t-score: {t_score:.3f}")
    print(f"Critical t-value: ±{t_critical:.3f}")

    # Decision
    if abs(t_score) > t_critical:
        print("Reject the null hypothesis: There is a significant difference in exam scores.")
    else:
        print("Fail to reject the null hypothesis: No strong evidence of a difference in exam scores.")

# Given data
group_A_mean = 78
group_A_std = 10
group_A_n = 30
group_B_mean = 85
group_B_std = 12
group_B_n = 30

# Run the test
two_tailed_t_test(group_A_mean, group_A_std, group_A_n, group_B_mean, group_B_std, group_B_n)
# Out:
# Degrees of Freedom: 29
# Calculated t-score: -2.455
# Critical t-value: ±2.045
# Reject the null hypothesis: There is a significant difference in exam scores.

# %% [markdown]
# **7.One-sample t-test:**
#
# **A manufacturer claims that the mean weight of their cereal boxes is 500 grams. A sample of 30 cereal boxes has a mean weight of 490 grams and a standard deviation of 20 grams. Conduct a one-sample t-test to determine if there is evidence to support the manufacturer's claim at a significance level of 0.05.**
#
# A one-sample t-test is used to determine whether the mean of a single sample is significantly different from a known population mean.
#
# ![One-Sample-t-test-representation.jpg](data:image/jpeg;base64,...)
#
# Sample Mean $\bar x$ = 490 grams
#
# Sample Standard Deviation s = 20 grams
#
# Sample Size n = 30
#
# Significance Level α = 0.05
#
# We will conduct a one-sample t-test to determine whether there is sufficient evidence to reject the manufacturer's claim.
#
# **Step 1: Define the Hypotheses**
#
# Null Hypothesis $H_0$: The mean weight of the cereal boxes is 500 grams (as claimed by the manufacturer. 𝜇=500
#
# Alternative Hypothesis $H_A$: The mean weight is different from 500 grams.
#
# Since we are testing for any difference (either higher or lower), this is a two-tailed test.
#
# Step 2: Determine the Test Statistic
#
# We use the t-test formula for a one-sample test:
#
# $t= (\bar x - \mu_0) \div (s/\sqrt(n))$
#
# Substituting the given values:
# $t=(490 - 500) \div (20/\sqrt(30))$
#
# $t=(-10) \div (20/5.477)$
#
# $t=-2.739$
#
# Thus, our computed t-statistic is -2.739.
#
# **Step 3: Find the Critical t-Value**
#
# Since this is a two-tailed test, we need the critical t-value for
#
# Significance level (α = 0.05)
# Degrees of freedom (df) = n-1 =30 -1=29
#
# Using a t-table or Python, the critical t-value for a two-tailed test at
# α=0.05 and df = 29 is:
#
# ${t}_{critical}$=±2.045
#
# **Step 4: Compare t-Statistic with Critical Value**
#
# Computed t-statistic: -2.739
#
# Critical t-values: ±2.045
#
# Since:
# ${t}_{statistic}$ < ${t}_{critical}$
#
# (i.e.,-2.739<-2.045)
#
# We reject the null hypothesis.
#
# **Step 5: Compute the p-Value**
#
# The p-value represents the probability of obtaining a test statistic at least as extreme as the one observed, assuming the null hypothesis is true.
#
# For a two-tailed test, the p-value is calculated as:
#
# $p=2 \times P(T<−2.739) $
#
# Using Python, we found: $𝑝 = 0.0104 $
# Since $p=0.0104<α=0.05$, we have sufficient evidence to reject $𝐻_0$
#
# **Step 6: Interpretation & Conclusion**
# Since our computed t-statistic (-2.739) is beyond the critical t-value (-2.045) and our p-value (0.0104) is less than 0.05, we reject the null hypothesis.
#
# Conclusion:
# At a 0.05 significance level, we have strong statistical evidence that the mean weight of the cereal boxes is significantly different from 500 grams.
#
# This means that the manufacturer's claim is likely incorrect, and further investigation may be needed to check underfilling or overfilling issues in production.

# %%
import scipy.stats as stats
import numpy as np

# Given data
sample_mean = 490  # Sample mean weight
sample_std = 20     # Sample standard deviation
sample_size = 30    # Sample size
claimed_mean = 500  # Claimed population mean
alpha = 0.05        # Significance level

# Degrees of freedom
df = sample_size - 1

# Compute t-statistic
t_statistic = (sample_mean - claimed_mean) / (sample_std / np.sqrt(sample_size))

# Find critical t-value for two-tailed test (alpha = 0.05)
t_critical = stats.t.ppf(1 - alpha/2, df)  # Two-tailed test

# Compute p-value for two-tailed test
p_value = 2 * (1 - stats.t.cdf(abs(t_statistic), df))

# Print results
print(f"T-Statistic: {t_statistic:.3f}")
print(f"Critical T-Value: ±{t_critical:.3f}")
print(f"P-Value: {p_value:.4f}")

# Decision Rule
if abs(t_statistic) > t_critical:
    print("Reject the null hypothesis: The mean weight is significantly different from 500 grams.")
else:
    print("Fail to reject the null hypothesis: No significant evidence that the mean weight is different from 500 grams.")
# Out:
# T-Statistic: -2.739
# Critical T-Value: ±2.045
# P-Value: 0.0104
# Reject the null hypothesis: The mean weight is significantly different from 500 grams.

# %% [markdown]
# **8.Two-sample t-test:**
#
# **A researcher wants to compare the mean reaction times of two different groups of participants in a driving simulation study. Group A has a mean reaction time of 0.6 seconds with a standard deviation of 0.1 seconds, while Group B has a mean reaction time of 0.55 seconds with a standard deviation of 0.08 seconds. Conduct a two-sample t-test to determine if there is a significant difference in mean reaction times between the groups at a significance level of 0.01.**
#
# **Ans:**
#
# Group A:
#
# Mean reaction time $\bar x_A$  = 0.6 seconds
#
# Standard deviation $s_A$ = 0.1 seconds
#
# Sample size $𝑛_A$ = 30
#
# Group B:
#
# Mean reaction time $\bar x_B$= 0.55 seconds
#
# Standard deviation $s_B$ = 0.08 seconds
#
# Sample size $n_B$=30
#
# Significance Level: α=0.01
#
#
# Test Type: Two-sample t-test (Welch’s t-test, assuming unequal variances).
#
# **Step 1: Define the Hypotheses**
#
# Null Hypothesis ( $H_0$ ): There is no significant difference in the mean reaction times between Group A and Group B.
#
# $H_0$ : $μ_A$ =$μ_B$
#
# or equivalently,  $H_0$ : $μ_A$ - $μ_B$=0
#
# where: μ1 = Mean exam score of Group 1.
#
# μ2 = Mean exam score of Group 2.
#
# Alternative Hypothesis ( $H_A$ ): There is a significant difference in the mean exam scores between the two groups (either higher or lower).  $H_A$ : $μ_A$ ≠ $μ_B$
#
# or equivalently,  $H_A$ : $μ_A$  -  $μ_B$ ≠0
#
# **Step 2: Compute the Test Statistic**
#
# $t= \frac{\bar x_A - \bar x_B} {\sqrt{(s_A)^2/n_A + (s_B)^2/n_B}}$
#
#
# Substituting the given values:
#
# $t=\frac{0.6 - 0.55} {\sqrt{(0.1)^2/30 + (0.08)^2/30}}$
#
# $t= \frac{0.05} {\sqrt{(0.01/30 + (0.0064)/30}}$
#
# $t= \frac{0.05} {\sqrt{0.0003333 + 0.0002133}}$
#
# $t= \frac{0.05} {\sqrt{0.0005467}}$
#
# $t= \frac{0.05} {0.02338}$
#
# $t=2.138$
#
# Thus, our computed $t_{statistic}$ is 2.138.
#
# **Step 3: Find the Critical t-Value**
#
# Since this is a two-tailed test at α=0.01, we need to find the critical t-value for our degrees of freedom.
#
# Degrees of Freedom (Welch’s Formula)
# Since the sample variances are not assumed to be equal, we use Welch’s approximation for degrees of freedom
#
# $df = \frac{(s_A ^2/n_A \dotplus  s_B^2/n_B)^2}{(s_A^2/n_A)^2/n_A -1)+(s_B^2/n_B)^2/n_B -1)}$
#
# Substituting values:
#
# $df = \frac{(0.0005467)^2}{(0.0003333)^2/29)+(0.0002133)^2/29)}$
#
# $df \approx 55.33$
#
# Using a t-table or Python, the critical  t-value for $df \approx 55.33 $
#
# at α=0.01 (two-tailed) is:$ \pm 2.668 $
#
# **Step 4: Compare t-Statistic with Critical Value**
#
# Computed t-statistic: 2.138
#
# Critical t-values: ±2.668
#
# Since:
#
# t =2.138 < $t_{critical}$=2.668
# we fail to reject the null hypothesis.
#
# **Step 5: Compute the p-Value**
# The p-value represents the probability of obtaining a test statistic as extreme as the observed one, assuming $H_0$ is true.
#
# For a two-tailed test, the p-value is calculated as:
#
# $P= 2 \times (P > \big|{t}\big|)$
#
# $P=0.0369$
#
# Since p=0.0369>α=0.01, we do not have enough evidence to reject $H_0$
#
# Since $\big|𝑡\big|$ =2.138  is less than  2.668 and p-value (0.0369) is greater than 0.01, we fail to reject the null hypothesis.
#
# ![output (2).png](data:image/png;base64,...)

# %%
mean_A = 0.6   # Mean reaction time (seconds)
std_A = 0.1    # Standard deviation (seconds)
n_A = 30       # Sample size

# Given data for Group B
mean_B = 0.55  # Mean reaction time (seconds)
std_B = 0.08   # Standard deviation (seconds)
n_B = 30       # Sample size

# Significance level
alpha = 0.01

# Compute t-statistic for two-sample independent t-test (Welch's t-test for unequal variances)
t_statistic, p_value = stats.ttest_ind_from_stats(mean1=mean_A, std1=std_A, nobs1=n_A,
                                                  mean2=mean_B, std2=std_B, nobs2=n_B,
                                                  equal_var=False)  # Welch's t-test

# Compute degrees of freedom using Welch’s formula
df = ( (std_A**2/n_A + std_B**2/n_B)**2 ) / \
     ( (std_A**2/n_A)**2 / (n_A - 1) + (std_B**2/n_B)**2 / (n_B - 1) )

# Find critical t-value for two-tailed test
t_critical = stats.t.ppf(1 - alpha/2, df)

# Print results
print(f"T-Statistic: {t_statistic:.3f}")
print(f"Degrees of Freedom: {df:.2f}")
print(f"Critical T-Value (Two-Tailed): ±{t_critical:.3f}")
print(f"P-Value: {p_value:.4f}")

# Decision Rule
if abs(t_statistic) > t_critical:
    print("Reject the null hypothesis: There is a significant difference in reaction times between Group A and Group B.")
else:
    print("Fail to reject the null hypothesis: No significant difference in reaction times between Group A and Group B.")
# Out:
# T-Statistic: 2.138
# Degrees of Freedom: 55.33
# Critical T-Value (Two-Tailed): ±2.668
# P-Value: 0.0369
# Fail to reject the null hypothesis: No significant difference in reaction times between Group A and Group B.

# %% [markdown]
# **9.Process Control Example:**
#
# **A call center manager implements a new training program aimed at reducing call waiting times. The average waiting time before the training program was 4.5 minutes, and after the program, it is measured to be 4.0 minutes with a standard deviation of 0.8 minutes. Conduct a hypothesis test to determine if there is evidence that the training program has reduced waiting times, using a significance level of 0.05.**
#
# **Ans:**
#
# Here NULL Hypothesis $H_0$ is training program did not reduce waiting time below 4.5 minutes
#
# i.e $H_0 : \mu =4.5 minutes$
#
# Alernate Hypothesis $H_A$ is the traininh program reduced the waiting time belwow 4.5 minutes
#
# i.e $H_A : \mu < 4.5 minutes$
#
# so we carry out a left-tailed test because we are specifically looking for a decrease in waiting times.
#
# formula
#
# $t=\frac{\bar x - \mu_o }{s/\sqrt(n)}$
#
# Substituting values:
# $t=\frac{4 -4.5}{0.8/\sqrt(30)}$
#
# $t=\frac{-0.5}{0.8/5.477}$
#
# $t=-3.423$
#
# This is our $t_{statisitics}$=-3.423
# The $t_{critical}$ for $\alpha$=0.05 with df =29 is -1.699
#
# P-value here for p =P(T <  $t_{statisitics}$) is 0.0009 where is very much less than $\alpha$=0.05 , so we reject NULL Hypothesis $H_0$
#
# **Conclusion:**
#
# Since the t-statistic is more extreme than the critical value and the p-value is very small, we have strong statistical evidence to reject the null hypothesis.
#
# At a 0.05 significance level, we conclude that the training program significantly reduced call waiting times.
#
# ![output (1).png](data:image/png;base64,...)

# %%
import scipy.stats as stats
import numpy as np # Import the numpy library

# Given data
before_mean = 4.5  # Mean waiting time before training
after_mean = 4.0   # Mean waiting time after training
after_std = 0.8    # Standard deviation after training
n = 30             # Sample size
alpha = 0.05       # Significance level

# Compute t-statistic
t_statistic = (after_mean - before_mean) / (after_std / np.sqrt(n))

# Compute degrees of freedom
df = n - 1  # Degrees of freedom

# Find critical t-value for left-tailed test
t_critical = stats.t.ppf(alpha, df)

# Compute p-value for left-tailed test
p_value = stats.t.cdf(t_statistic, df)

# Print results
print(f"T-Statistic: {t_statistic:.3f}")
print(f"Degrees of Freedom: {df}")
print(f"Critical T-Value (Left-Tailed): {t_critical:.3f}")
print(f"P-Value: {p_value:.4f}")

# Decision Rule
if t_statistic < t_critical:
    print("Reject the null hypothesis: The training program significantly reduced waiting times.")
else:
    print("Fail to reject the null hypothesis: No significant evidence that the training program reduced waiting times.")
# Out:
# T-Statistic: -3.423
# Degrees of Freedom: 29
# Critical T-Value (Left-Tailed): -1.699
# P-Value: 0.0009
# Reject the null hypothesis: The training program significantly reduced waiting times.

# %% [markdown]
# **10.Interpreting Results:**
#
# **After conducting a hypothesis test, the calculated p-value is 0.02. What can you conclude about the null hypothesis based on this result, assuming a significance level of 0.05?**
#
# **Ans:**
#
# Calculated p-value: 0.02
#
# Significance level (α): 0.05
#
# The decision rule in hypothesis testing is:
#
# a) If p≤α → Reject the null hypothesis (  H0  ) (There is significant evidence to support the alternative hypothesis).
#
# b) If p>α → Fail to reject the null hypothesis (  H0 ) (There is not enough evidence to support the alternative hypothesis).
#
# Since p=0.02 is less than α=0.05, we reject the null hypothesis.
#
# **Conclusion:**
#
# We have enough statistical evidence to conclude that the effect being tested is statistically significant. This means that the observed results are unlikely to have occurred by random chance under the null hypothesis. The alternative hypothesis ( HA ) is supported at the 5% significance level.
#
# ![output.png](data:image/png;base64,...)
#
# **Explanation of the Visualization:**
#
# The black curve represents the standard normal distribution (bell-shaped curve). The red-shaded region represents the rejection region (α=0.05). If the test statistic falls in this region, we reject  H0
#
# The blue-shaded region represents the p-value region (p=0.02). Since it falls inside the rejection region, we reject  H0
#
# Dashed red line represents the critical value at α=0.05.
#
# Dashed blue line represents the observed test statistic corresponding to p=0.02.
#
# **Conclusion from the Visualization:** Since the blue region (p-value) is within the red rejection region, we reject the null hypothesis. This means the result is statistically significant at 𝛼 = 0.05 α=0.05, providing evidence to support the alternative hypothesis.
#
# This visual confirms that we have enough evidence to reject H0!
