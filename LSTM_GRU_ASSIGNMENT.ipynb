# %% [markdown]
# <a href="https://colab.research.google.com/github/SowjanyaKiran/sowjanya-/blob/main/LSTM_GRU_ASSIGNMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing important libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM ,GRU
from tensorflow.keras.callbacks import EarlyStopping
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading the data
try:
    df = pd.read_csv('/content/LSTM DATA.txt', sep='\t')
except:
    with open('/content/LSTM DATA.txt') as f:
        [print(f"{i+1}: {line.strip()}") for i, line in zip(range(10), f)]

# %%
#Exactracting the data
data = df.copy()
data.head()
# Out:
#   The Project Gutenberg eBook of Pride and Prejudice
# 0  This ebook is for the use of anyone anywhere i...
# 1  most other parts of the world at no cost and w...
# 2  whatsoever. You may copy it, give it away or r...
# 3  of the Project Gutenberg License included with...
# 4  at www.gutenberg.org. If you are not located i...

# %%
print(df.columns)
# Out:
# Index(['The Project Gutenberg eBook of Pride and Prejudice'], dtype='object')

# %%
df.columns = ['Text']

# %%
import re
text = re.sub(r'[^a-zA-Z\s]', '', text)
text = text.lower()

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])
total_words = len(tokenizer.word_index) + 1

# Create input sequences
input_sequences = []
for line in text.split("\n"):
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(2, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

# Pad sequences
max_seq_len = max(len(x) for x in input_sequences)
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_seq_len, padding='pre'))

# Split features and labels
X, y = input_sequences[:, :-1], input_sequences[:, -1]
y = tf.keras.utils.to_categorical(y, num_classes=total_words)

# %%
def create_lstm_model():
    model = Sequential([
        Embedding(total_words, 100, input_length=max_seq_len - 1),
        LSTM(150),
        Dense(total_words, activation='softmax')
    ])
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
lstm_model = create_lstm_model()
lstm_model.fit(X, y, epochs=100, verbose=1, callbacks=[EarlyStopping(patience=2)])
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.0000e+00 - loss: 2.1991
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.4286 - loss: 2.1862
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5714 - loss: 2.1734
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5714 - loss: 2.1600
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.5714 - loss: 2.1455
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7143 - loss: 2.1294
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7143 - loss: 2.1109
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.7143 - loss: 2.0893
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.4286 - loss: 2.0637
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.4286 - loss: 2.0331
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.4286 - loss: 1.9963
# Epoch 12/100
# ...

# %%
def create_gru_model():
    model = Sequential([
        Embedding(total_words, 100, input_length=max_seq_len - 1),
        GRU(150),
        Dense(total_words, activation='softmax')
    ])
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

gru_model = create_gru_model()
gru_model.fit(X, y, epochs=100, verbose=1, callbacks=[EarlyStopping(patience=2)])
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.1429 - loss: 2.2054
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.2857 - loss: 2.1865
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.2857 - loss: 2.1678
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4286 - loss: 2.1490
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5714 - loss: 2.1296
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5714 - loss: 2.1096
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7143 - loss: 2.0885
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8571 - loss: 2.0660
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8571 - loss: 2.0418
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 2.0155
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 1.9867
# Epoch 12/100
# ...

# %%
def predict_next_word(model, seed_text, n_words=1):
    for _ in range(n_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_seq_len - 1, padding='pre')
        predicted = model.predict(token_list, verbose=0)
        output_word = tokenizer.index_word[np.argmax(predicted)]
        seed_text += " " + output_word
    return seed_text

# %%
print(predict_next_word(lstm_model, "it is a truth"))
print(predict_next_word(gru_model, "i hope you"))
# Out:
# it is a truth our
# i hope you our

# %%
print(predict_next_word(lstm_model, "what does it "))
print(predict_next_word(gru_model, "should i "))
# Out:
# what does it  our
# should i  our
